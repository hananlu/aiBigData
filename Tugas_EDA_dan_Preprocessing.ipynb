# %% [markdown]
# <a href="https://colab.research.google.com/github/hananlu/aiBigData/blob/master/Tugas_EDA_dan_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Kerjakan tugas berikut sesuai dengan ketentuan dan pertanyaan yang diberikan**
#
#
# 1. Kerjakan soal sesuai dengan pertanyaan yang diberikan, serta berikan alasan dari pertanyaan tidak hanya menampilkan hasil code
# 2. Beri identitas pada soal yang diberikan
# 3. Simpan format hasil pekerjaan dalam bentuk pdf kemudian diupload ke LMS
#
# ---
#
# ##### Nama:
# ##### NIM:
# ##### Kelas:
#
# ##### Link dataset: https://raw.githubusercontent.com/hananlu/aiBigData/refs/heads/master/Dataset/abalone_data.csv

# %% [markdown]
# #### Load Library

# %% [markdown]
# #### 1. Tampilkan 5 baris pertama dari dataset yang diberika

# %% [markdown]
# #### 1. Penjelasan code
# ---
# Tulis penjelasan disini

# %% [markdown]
# #### 2. Berapa jumlah baris dan kolom dataset?

# %% [markdown]
# #### 2. Penjelasan code
# ---
# Tulis penjelasan disini

# %% [markdown]
# #### 3. Tampilkan tipe data setiap kolom

# %% [markdown]
# #### 3. Penjelasan code
# ---
# Tulis penjelasan disini

# %% [markdown]
# #### 4. Kolom mana yang merupakan variabel kategorikal?

# %% [markdown]
# #### 4. Penjelasan code
# ---
# Tulis penjelasan disini

# %% [markdown]
# #### 5. Hitung statistik deskriptif untuk seluruh kolom numerik

# %% [markdown]
# #### 5. Penjelasan code
# ---
# Tulis penjelasan disini

# %% [markdown]
# #### 6. Statistik pada Dataset Abalone
#
# a. Berapa rata-rata panjang (`Length`) abalone?
# b. Berapa nilai maksimum dari `Whole weight`?

# %% [markdown]
# #### 6. Penjelasan code
# ---
# Tulis penjelasan disini

# %% [markdown]
# #### 7. Hitung jumlah abalone berdasarkan jenis kelamin

# %% [markdown]
# #### 7. Penjelasan code
# ---
# Tulis penjelasan disini

# %% [markdown]
# #### 8. Buat scatter plot antara Length dan Whole weight

# %% [markdown]
# #### 8. Penjelasan code
# ---
# Tulis penjelasan disini

# %% [markdown]
# #### 9. Buat bar chart jumlah abalone berdasarkan Sex

# %% [markdown]
# #### 9. Penjelasan code
# ---
# Tulis penjelasan disini

# %% [markdown]
# #### 10. Periksa apakah terdapat missing value, jika ada atasi permasalahan tersebut

# %% [markdown]
# #### 10. Penjelasan code
# ---
# Tulis penjelasan disini

# %% [markdown]
# #### 11. Ubah kolom Sex menjadi numerik menggunakan encoding

# %% [markdown]
# #### 11. Penjelasan code
# ---
# Tulis penjelasan disini

# %% [markdown]
# #### 12. Buat kolom baru Age dari Rings dengan rumus untuk mendapatkan Age adalah `Rings + 1.5`

# %% [markdown]
# #### 12. Penjelasan code
# ---
# Tulis penjelasan disini

# %% [markdown]
# #### 13. Deteksi outlier pada kolom Whole weight menggunakan IQR

# %% [markdown]
# #### 13. Penjelasan code
# ---
# Tulis penjelasan disini

# %% [markdown]
# #### 14. Lakukan normalisasi atau standarisasi pada dataset

# %% [markdown]
# #### 14. Penjelasan code, kolom apa saja yang dipilih? kenapa memilih kolom tersebut? mengapa memilih standarisasi atau normalisasi?
# ---
# Tulis penjelasan disini

# %% [markdown]
# #### 15. Hitung rata-rata Whole weight berdasarkan jenis kelamin (Sex)

# %% [markdown]
# #### 15. Penjelasan code
# ---
# Tulis penjelasan disini

# %% [markdown]
# #### 16. Hitung rata-rata Length dan Diameter untuk setiap jenis kelamin

# %% [markdown]
# #### 16. Penjelasan code
# ---
# Tulis penjelasan disini

# %% [markdown]
# #### 17. Urutkan hasil rata-rata Whole weight berdasarkan Sex dari terbesar ke terkecil

# %% [markdown]
# #### 17. Penjelasan code
#
#
# ---
# Tulis penjelasan disini
