# %% [markdown]
# ---
# ### Nama:
# ### NIM:
# ### Kelas:
# ---

# %% [markdown]
# #### Link Dataset
# ##### https://raw.githubusercontent.com/hananlu/basicPython/refs/heads/master/Dataset/tetuanCityPowerConsumption.csv

# %% [markdown]
# ## 1. Tampilkan data seperti berikut, kemudian jelaskan
# ![1](https://raw.githubusercontent.com/hananlu/basicPython/refs/heads/master/Images/Tetuan/1.png)

# %% [markdown]
# ## 2. Tampilkan data seperti berikut, kemudian jelaskan
# ![2](https://raw.githubusercontent.com/hananlu/basicPython/refs/heads/master/Images/Tetuan/2.png)

# %% [markdown]
# ##3. Tampilkan informasi dataset seperti berikut, jelaskan apa yang sedang dilakukan
# ![3](https://raw.githubusercontent.com/hananlu/basicPython/refs/heads/master/Images/Tetuan/3.png)

# %% [markdown]
# ##4. Tampilkan informasi dataset seperti berikut, jelaskan apa yang sedang dilakukan
# ![4](https://raw.githubusercontent.com/hananlu/basicPython/refs/heads/master/Images/Tetuan/4.png)

# %% [markdown]
# ##5. Buat tampilan seperti berikut, jelaskan apa yang sedang dilakukan. Termasuk jenis visualisasi apa yang digunakan
# ![5](https://raw.githubusercontent.com/hananlu/basicPython/refs/heads/master/Images/Tetuan/5.png)

# %% [markdown]
# ##6. Buat tampilan seperti berikut, jelaskan apa yang sedang dilakukan. Termasuk jenis visualisasi apa yang digunakan
# ![6](https://raw.githubusercontent.com/hananlu/basicPython/refs/heads/master/Images/Tetuan/6.png)

# %% [markdown]
# ##7. Buat tampilan seperti berikut, jelaskan apa yang sedang dilakukan. Termasuk jenis visualisasi apa yang digunakan
# ![link text](https://raw.githubusercontent.com/hananlu/basicPython/refs/heads/master/Images/Tetuan/7.png)

# %% [markdown]
# ##8. Buat tampilan seperti berikut, jelaskan apa yang sedang dilakukan. Termasuk jenis visualisasi apa yang digunakan
# ![link text](https://raw.githubusercontent.com/hananlu/basicPython/refs/heads/master/Images/Tetuan/8.png)

# %% [markdown]
# ##9. Tampilkan korelasi data seperti berikut, jelaskan apa tujuan dilakukan hal ini
# ![link text](https://raw.githubusercontent.com/hananlu/basicPython/refs/heads/master/Images/Tetuan/9.png)

# %% [markdown]
# ##10. Buat tampilan seperti berikut, jelaskan apa yang sedang dilakukan. Termasuk jenis visualisasi apa yang digunakan
# ![link text](https://raw.githubusercontent.com/hananlu/basicPython/refs/heads/master/Images/Tetuan/10.png)

# %% [markdown]
# ##11. Lakukan split data kemudian atur ukuran test size menjadi 20% dari tola dataset selanjutnya buat model `LinearRegression` dan evaluasi hasilnya

# %% [markdown]
# ##12. Buat Model `RandomForestRegressor` kemudian evaluasi hasilnya

# %% [markdown]
# ##13. Buat visualisasi seperti berikut untuk membandingkan hasil model, jelaskan apa arti dari visualisasi tersebut.
# ![link text](https://raw.githubusercontent.com/hananlu/basicPython/refs/heads/master/Images/Tetuan/13.png)

# %% [markdown]
# ##14. Lakukan feature importance menggunakan `RandomForestRegressor` pilih 4 feature terpenting kemudian training dan tuning menggunakan hyperparameter
# ![link text](https://raw.githubusercontent.com/hananlu/basicPython/refs/heads/master/Images/Tetuan/14_1.png)
#
# ![link text](https://raw.githubusercontent.com/hananlu/basicPython/refs/heads/master/Images/Tetuan/14_2.png)

# %% [markdown]
# ##15. Buat visualisasi seperti berikut, kemudian jelaskan apa maksud dari visualisasi yang ditampilkan
# ![link text](https://raw.githubusercontent.com/hananlu/basicPython/refs/heads/master/Images/Tetuan/15.png)

# %% [markdown]
# ## Hasil Pengerjaan disimpan dalam bentuk pdf dan sertakan juga link referensinya
