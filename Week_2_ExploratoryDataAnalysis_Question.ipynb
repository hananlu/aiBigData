# %% [markdown]
# <a href="https://colab.research.google.com/github/hananlu/aiBigData/blob/master/Week_2_ExploratoryDataAnalysis_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Load Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Create Dataset

# %%
data = {
    "Name": [
        "Andi", "Budi", "Siti", "Rina", "Doni",
        "Lina", "Agus", "Maya", "Rudi", "Tono"
    ],
    "Age": [
        21, 22, 20, 23, 21,
        24, 22, 23, 25, 21
    ],
    "City": [
        "Jakarta", "Bandung", "Surabaya", "Jakarta", "Bandung",
        "Surabaya", "Jakarta", "Bandung", "Surabaya", "Jakarta"
    ],
    "Salary": [
        5000, 6000, 5500, 7000, 6500,
        7200, 5800, 6100, 6800, 5900
    ]
}


df = pd.DataFrame(data)
# Out:
#    Name  Age      City  Salary
# 0  Andi   21   Jakarta    5000
# 1  Budi   22   Bandung    6000
# 2  Siti   20  Surabaya    5500
# 3  Rina   23   Jakarta    7000
# 4  Doni   21   Bandung    6500

# %% [markdown]
# ### View Dataset (head, tail, shape)

# %% [markdown]
# ### Dataset Information

# %% [markdown]
# ### Statistical Description (Get mean, median, mode, std)

# %% [markdown]
# ### Select Columns or Rows

# %% [markdown]
# ### Grouping Data

# %% [markdown]
# ### Handling Missing Value

# %% [markdown]
# ### View Distribution Values

# %% [markdown]
# ### Scatter Plot (Age vs Salary)

# %% [markdown]
# ### Pie Plot City Distribution

# %% [markdown]
# ### Load Dataset
#
# https://raw.githubusercontent.com/selva86/datasets/refs/heads/master/Cars93.csv

# %% [markdown]
# ### Question
#
# 1. Tampilkan 5 baris pertama dari dataset.
# 2. Berapa jumlah baris dan kolom pada dataset?
# 3. Tampilkan nama seluruh kolom pada dataset.
# 4. Tentukan tipe data dari setiap kolom apakah sudah sesuai? jika belum perbaiki data tersebut.
# 5. Berapa harga mobil rata-rata (Price)?
# 6. Berapa nilai maksimum Horsepower?
# 7. Berapa nilai minimum MPG.city?
# 8. Hitung median EngineSize.
# 9. Berapa jumlah mobil untuk setiap Manufacturer?
# 10. Berapa jumlah mobil berdasarkan Type?
# 11. Tentukan Manufacturer dengan jumlah mobil terbanyak.
# 12. Buat scatter plot untuk menganalisis hubungan Horsepower vs Price apakah mobil dengan horsepower tinggi memiliki harga lebih mahal?
# 13. Buat bar chart untuk Rata-rata Price berdasarkan Type mobil. Type mobil mana yang paling mahal?
# 14. Berdasarkan analisis yang dilakukan Sebutkan 3 insight penting dari dataset.
